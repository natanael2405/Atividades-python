# %% [markdown]
# <a href="https://colab.research.google.com/github/natanael2405/Atividades-python/blob/main/Atividade1agostoNatanael.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# questao 4
Numero = int(input("digite o numero:  "))

if (Numero % 2) == 1:
 print("impar")

else:
 print("par")

# %%
# questao 5
nota1 = int(input("digite a sua primeira nota:  "))
nota2 = int(input("digite a sua primeira nota:  "))

media = (nota1 + nota2) / 2

if media >= 7:
 print("aprovado")

elif media >= 5 and media <= 7:
 print("recuperação")

else:
 print("reprovado")

print(media)

# %%
# questao 6
n1 = int(input("digite um numero:  "))
n2 = int(input("digite um numero:  "))
n3 = int(input("digite um numero:  "))

if n1 > n2 and n1 > n3:
 print("o numero", n1 , "é o maior")

elif n2 > n1 and n2 > n3:
 print("o numero", n2 , "é o maior")

else:
 print("o numero", n3 ,"é o maior")

# %%
# questao 7
contador = 0

while contador < 10:
    contador = contador + 1
    print(contador)

# %%
#questao 8
soma_total = 0
contador = 0

while contador < 15:
    contador += 1
    soma = contador + contador
    soma_total += soma

print(soma_total)

# %%
#questao 9
contador = 0
for i in range(2,50,2):
 print(i)
 contador += 1
print("total de numero pares foi",contador)

# %%
# questao 10
soma = 0

for i in range(8):
    numero = int(input("Digite o número: "))
    if numero > 0:
        soma += numero

print("A soma dos números positivos é:",soma)

# %%
# questao 11
maior = int(input("Digite o número: "))

for i in range(5):
    numero = int(input("Digite o número: "))
    if numero > maior:
        maior = numero

print("O maior número informado foi:", maior)

# %%
# questao 12
numero = int(input("digite o numero da tabuada: "))

for i in range(1, 11):
    resultado = numero * i
    print(numero, "X", i, "=", resultado)

# %%
#questao 13
senha = 1234

senha_digitada = int(input("digite a senha:  "))
tentativa = 0

if senha_digitada == senha:
 print("acesso permitido")

else:
 tentativa += 1

print("numero de tentativas", tentativa)

# %%
# questao 14
n_secreto = 7
tentativas = 0

n_digitado = int(input("escreva o numero: "))

while n_digitado < 7 or n_digitado > 7:
    tentativas += 1
    if n_digitado < 7:
        print("tente um numero maior")
    else:
        print("tente um numero menor")
    n_digitado = int(input("escreva o numero: "))

tentativas += 1
print("você acertou e foram",tentativas,"tentativas")

# %%
#questao 15
quantidade = 0
positivos = 0
negativos = 0
soma = 0

n_digitado = int(input("digite um numero (0 para parar): "))

while n_digitado > 0 or n_digitado < 0:
    quantidade = quantidade + 1
    soma = soma + n_digitado

    if n_digitado > 0:
        positivos = positivos + 1
    else:
        negativos = negativos + 1

    n_digitado = int(input("digite um numero (0 para parar): "))

print("quantidade de numeros digitados:", quantidade)
print("quantidade de positivos:", positivos)
print("quantidade de negativos:", negativos)
print("soma de todos os numeros:", soma)
